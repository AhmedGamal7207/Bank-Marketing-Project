# %% [markdown]
# <div style="
#     max-width: 1200px;
#     margin: 18px auto;
#     padding: 50px 30px;
#     background: rgba(120, 120, 120, 0.05);
#     border-radius: 20px;
#     border: 1px solid rgba(120, 120, 120, 0.1);
#     box-shadow: 0 10px 30px rgba(0,0,0,0.15);
#     text-align: center;
# ">
#     <h1 style="
#         margin: 0;
#         background: linear-gradient(90deg, #6a11cb 0%, #2575fc 100%);
#         -webkit-background-clip: text;
#         -webkit-text-fill-color: transparent;
#         font-family: 'Segoe UI', sans-serif;
#         font-weight: 800;
#         font-size: 3em;
#     ">
#         Bank Marketing Project - EDA
#     </h1>
#     <p style="
#         font-size: 1.2em;
#         opacity: 0.8;
#         margin: 15px 0 0 0;
#         font-family: 'Segoe UI', sans-serif;
#         letter-spacing: 1px;
#         line-height: 1.8;
#     ">
#        Track: AI - Intake 46 - Alexandria
#        <br/>
#        Subject: Bank Marketing Project - EDA Phase
#        <br/>
#        Team Members: Abdallah Mohamed - Ahmed Gamal - Ahmed Saleem
#     </p>
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 12px 0;
#   padding: 16px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.08);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.10);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <!-- Left Accent (Theme) -->
#   <div style="
#     position: absolute;
#     left: 0; top: 0; bottom: 0;
#     width: 5px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <div style="
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     color: inherit;
#   ">
#     <p style="
#       margin: 0;
#       font-size: 1em;
#       line-height: 1.75;
#       opacity: 0.90;
#     ">
#       Notebook (1) (eda.ipynb): in this notebook, we will apply Exploratory Data Analysis on the Bank Marketing Dataset. We will answer all the questions mentioned in the README.md file extracted during business understanding phase.
#     </p>
#
#   </div>
# </div>

# %% [markdown]
# <div style="
#     max-width: 1200px;
#     margin: 18px auto;
#     padding: 18px 25px;
#     background: linear-gradient(90deg, #5e0ab9 0%,#6a11cb 30%, #3f84fd 100%);
#     border-radius: 14px;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.2);
#     text-align: center;
# ">
#     <h2 style="
#         color: white;
#         margin: 0;
#         letter-spacing: 2px;
#         font-weight: 700;
#         font-family: 'Segoe UI', sans-serif;
#     ">
#         1. Packages and Data Loading
#     </h2>
#
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     1.1 Importing Libraries
#   </h3>
# </div>

# %%
# Data Dealers
import numpy as np
import pandas as pd


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import tools.plot_helper as our_plots

print("All packages were imported successfully!")
# Out:
# All packages were imported successfully!

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     1.2 Loading Data
#   </h3>
# </div>

# %%
df = pd.read_csv("dataset/bank-full.csv", sep=";")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# <div style="
#     max-width: 1200px;
#     margin: 18px auto;
#     padding: 18px 25px;
#     background: linear-gradient(90deg, #5e0ab9 0%,#6a11cb 30%, #3f84fd 100%);
#     border-radius: 14px;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.2);
#     text-align: center;
# ">
#     <h2 style="
#         color: white;
#         margin: 0;
#         letter-spacing: 2px;
#         font-weight: 700;
#         font-family: 'Segoe UI', sans-serif;
#     ">
#         2. Univariate Questions
#     </h2>
#
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 12px 0;
#   padding: 16px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.08);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.10);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <!-- Left Accent (Theme) -->
#   <div style="
#     position: absolute;
#     left: 0; top: 0; bottom: 0;
#     width: 5px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <div style="
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     color: inherit;
#   ">
#     <p style="
#       margin: 0;
#       font-size: 1em;
#       line-height: 1.75;
#       opacity: 0.90;
#     ">
#       In this stage, we will answer the questions that are related to exactly 1 variable in our dataset.
#       <br>
#       All questions can be found in the README.md file.
#     </p>
#
#   </div>
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q1 What is the overall success rate of the campaign?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["y"], title="Distribution of Target Variable", x_label="Target", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q2 What is the age distribution of contacted clients?
#   </h3>
# </div>

# %%
our_plots.plot_distribution(df["age"], title="Age Distribution", x_label="Age", bins=30, marginal="box")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q3 What are the most common job types?
#   </h3>
# </div>

# %%
our_plots.plot_bar(df["job"], title="Most Common Job Types", x_label="Job", y_label="Clients", sort_by="values", horizontal=True)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q4 What is the distribution of education levels?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["education"], title="Distribution of Education Levels", x_label="Education", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q5 How is call duration distributed?
#   </h3>
# </div>

# %%
our_plots.plot_distribution(df["duration"], title="Duration Distribution", x_label="Duration", bins=30, marginal="box")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q6 How many contacts are typically made per client?
#   </h3>
# </div>

# %%
our_plots.plot_distribution(df["campaign"], title="Contacting Distribution", x_label="Numer of Calls", bins=30, marginal="box")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q7 Which months have the highest call volume?
#   </h3>
# </div>

# %%
our_plots.plot_bar(df["month"], title="Months Call Volume", x_label="Month", y_label="Total Calls", sort_by="values", horizontal=True)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q8 What is the distribution of contact method (cellular vs telephone)?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["contact"], title="Distribution of Contacting Method", x_label="Contact Method", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q9 What is the distribution of marital status?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["marital"], title="Distribution of Marital Status", x_label="Marital Status", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q10 How many clients have housing loans?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["housing"], title="Housing Loan Distribution", x_label="Housing Loan", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q11 How many clients have personal loans?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["loan"], title="Personal Loan Distribution", x_label="Personal Loan", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q12 How many clients have credit in default?
#   </h3>
# </div>

# %%
our_plots.plot_pie(df["default"], title="Credit Distribution", x_label="Credit", y_label="Count", hole=0.5)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q13 How is the balance distributed?
#   </h3>
# </div>

# %%
our_plots.plot_distribution(df["balance"], title="Balance Distribution", x_label="Balance", bins=30, marginal="box")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q14 Which days have the highest call volume?
#   </h3>
# </div>

# %%
our_plots.plot_distribution(df["day"], title="Day Distribution", x_label="Day", bins=30, marginal="box")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     2. Q15 How many clients subscribed in a term deposit before?
#   </h3>
# </div>

# %%
our_plots.plot_bar(df["poutcome"], title="Previously Subscribed Analysis", x_label="Status", y_label="Count", sort_by="values", horizontal=False)

# %% [markdown]
# <div style="
#     max-width: 1200px;
#     margin: 18px auto;
#     padding: 18px 25px;
#     background: linear-gradient(90deg, #5e0ab9 0%,#6a11cb 30%, #3f84fd 100%);
#     border-radius: 14px;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.2);
#     text-align: center;
# ">
#     <h2 style="
#         color: white;
#         margin: 0;
#         letter-spacing: 2px;
#         font-weight: 700;
#         font-family: 'Segoe UI', sans-serif;
#     ">
#         3. Bivariate Questions
#     </h2>
#
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 12px 0;
#   padding: 16px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.08);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.10);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <!-- Left Accent (Theme) -->
#   <div style="
#     position: absolute;
#     left: 0; top: 0; bottom: 0;
#     width: 5px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <div style="
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     color: inherit;
#   ">
#     <p style="
#       margin: 0;
#       font-size: 1em;
#       line-height: 1.75;
#       opacity: 0.90;
#     ">
#       In this stage, we will answer the questions that are related to exactly 2 variables in our dataset.
#       <br>
#       All questions can be found in the README.md file.
#     </p>
#
#   </div>
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q16 How does job type affect subscription rate?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["job"], df["y"], title="Job Type vs Subscription", 
                           x_label="Job", y_label="Clients", legend_label="Subscription", sort_by="values")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q17 Does marital status influence deposit subscription?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["marital"], df["y"], title="Marital Status vs Subscription", 
                           x_label="Marital Status", y_label="Clients", legend_label="Subscription", sort_by="values")

# %%
# Calculate percentage of subscriptions by Marital Status
marital_subscription = df.groupby("marital")["y"].value_counts(normalize=True).unstack().fillna(0) * 100
print("Percentage of Subscriptions by Marital Status:")
print(f"{marital_subscription['yes'].iloc[0]:.2f}% of clients who are divorced subscribed.")
print(f"{marital_subscription['yes'].iloc[1]:.2f}% of clients who are married subscribed.")
print(f"{marital_subscription['yes'].iloc[2]:.2f}% of clients who are single subscribed.")
# Out:
# Percentage of Subscriptions by Marital Status:
# 11.95% of clients who are divorced subscribed.
# 10.12% of clients who are married subscribed.
# 14.95% of clients who are single subscribed.

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q18 Is education level correlated with subscription success?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["education"], df["y"], title="Education Level vs Subscription", 
                           x_label="Education", y_label="Clients", legend_label="Subscription", sort_by="values")

# %%
# Calculate percentage of subscriptions by Education level
education_subscription = df.groupby("education")["y"].value_counts(normalize=True).unstack().fillna(0) * 100
print("Percentage of Subscriptions by Education Level:")
print(f"{education_subscription['yes'].iloc[0]:.2f}% of clients with primary education subscribed.")
print(f"{education_subscription['yes'].iloc[1]:.2f}% of clients with secondary education subscribed.")
print(f"{education_subscription['yes'].iloc[2]:.2f}% of clients with tertiary education subscribed.")
print(f"{education_subscription['yes'].iloc[3]:.2f}% of clients with unknown education subscribed.")
# Out:
# Percentage of Subscriptions by Education Level:
# 8.63% of clients with primary education subscribed.
# 10.56% of clients with secondary education subscribed.
# 15.01% of clients with tertiary education subscribed.
# 13.57% of clients with unknown education subscribed.

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q19 Does call duration relate to subscription outcome?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_box(df["duration"], df["y"], title="Call Duration by Subscription", x_label="Subscription", y_label="Duration")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q20 Do clients with housing loans subscribe more?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["housing"], df["y"], title="Housing Loan vs Subscription", 
                           x_label="Housing", y_label="Clients", legend_label="Subscription", sort_by="values")

# %%
# Calculate percentage of subscriptions by housing status
housing_subscription = df.groupby("housing")["y"].value_counts(normalize=True).unstack().fillna(0) * 100
print("Percentage of Subscriptions by Housing Status:")
print(f"{housing_subscription['yes'].iloc[0]:.2f}% of clients without a housing loan subscribed.")
print(f"{housing_subscription['yes'].iloc[1]:.2f}% of clients with a housing loan subscribed.")
# Out:
# Percentage of Subscriptions by Housing Status:
# 16.70% of clients without a housing loan subscribed.
# 7.70% of clients with a housing loan subscribed.

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q21 Does contact method affect success rate?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["contact"], df["y"], title="Contact Method vs Subscription", 
                           x_label="Contact Method", y_label="Clients", legend_label="Subscription", sort_by="values")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q22 Which month has the highest subscription rate?
#   </h3>
# </div>

# %%
our_plots.plot_dual_axis_bar_line(df["month"], df["y"], title="Monthly Contacts and Subscription Rate")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q23 Does previous campaign outcome affect current subscription?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["poutcome"], df["y"], title="Previous Outcome vs Subscription", 
                           x_label="Previous Outcome", y_label="Clients", legend_label="Subscription", sort_by="values")

# %%
# Calculate percentage of subscriptions by previous outcome
poutcome_subscription = df.groupby("poutcome")["y"].value_counts(normalize=True).unstack().fillna(0) * 100
print("Percentage of Subscriptions by Previous Outcome:")
print(f"{poutcome_subscription['yes'].iloc[0]:.2f}% of clients with a failed previous contact subscribed.")
print(f"{poutcome_subscription['yes'].iloc[2]:.2f}% of clients with a successful previous contact subscribed.")
print(f"{poutcome_subscription['yes'].iloc[3]:.2f}% of clients with an unknown previous contact subscribed.")
# Out:
# Percentage of Subscriptions by Previous Outcome:
# 12.61% of clients with a failed previous contact subscribed.
# 64.73% of clients with a successful previous contact subscribed.
# 9.16% of clients with an unknown previous contact subscribed.

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q24 How does age differ between subscribers and non-subscribers?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_box(df["age"], df["y"], title="Age by Subscription", x_label="Subscription", y_label="Age")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q25 Does number of contacts affect success?
#   </h3>
# </div>

# %%
our_plots.plot_rate_line(df["previous"], df["y"], title="Subscription Rate by Previous Contacts", x_label="Previous Contacts")

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q26 Do clients with personal loans subscribe more?
#   </h3>
# </div>

# %%
our_plots.plot_grouped_bar(df["loan"], df["y"], title="Loan Status vs Subscription", 
                           x_label="Loan Status", y_label="Clients", legend_label="Subscription", sort_by="values")

# %%
# Calculate percentage of subscriptions by loan status
loan_subscription = df.groupby("loan")["y"].value_counts(normalize=True).unstack().fillna(0) * 100
print("Percentage of Subscriptions by Loan Status:")
print(f"{loan_subscription['yes'].iloc[0]:.2f}% of clients without a personal loan subscribed.")
print(f"{loan_subscription['yes'].iloc[1]:.2f}% of clients with a personal loan subscribed.")
# Out:
# Percentage of Subscriptions by Loan Status:
# 12.66% of clients without a personal loan subscribed.
# 6.68% of clients with a personal loan subscribed.

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q27 Is there a difference in balance distribution by subscription outcome?
#   </h3>
# </div>

# %%
our_plots.plot_class_histogram(df["balance"], df["y"], title="Balance Distribution by Subscription Outcome", x_label="Balance")
plt.show()

# %% [markdown]
# <div style="
#     max-width: 1200px;
#     margin: 18px auto;
#     padding: 18px 25px;
#     background: linear-gradient(90deg, #5e0ab9 0%,#6a11cb 30%, #3f84fd 100%);
#     border-radius: 14px;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.2);
#     text-align: center;
# ">
#     <h2 style="
#         color: white;
#         margin: 0;
#         letter-spacing: 2px;
#         font-weight: 700;
#         font-family: 'Segoe UI', sans-serif;
#     ">
#         4. Mutlivariate Questions
#     </h2>
#
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 12px 0;
#   padding: 16px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.08);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.10);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <!-- Left Accent (Theme) -->
#   <div style="
#     position: absolute;
#     left: 0; top: 0; bottom: 0;
#     width: 5px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <div style="
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     color: inherit;
#   ">
#     <p style="
#       margin: 0;
#       font-size: 1em;
#       line-height: 1.75;
#       opacity: 0.90;
#     ">
#       In this stage, we will answer the questions that are related to more than 2 variables in our dataset.
#       <br>
#       All questions can be found in the README.md file.
#     </p>
#
#   </div>
# </div>

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q26 Is the relationship between balance and success different across job types?
#   </h3>
# </div>

# %%
our_plots.plot_facet_grouped_box(
    df["balance"],
    df["job"],
    df["y"],
    title="Balance vs Subscription Across Job Types",
    x_label="Subscription",
    y_label="Balance",
    facet_label="Job",
    facet_col_wrap=4
)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q27 Is the relationship between duration and success different across job types?
#   </h3>
# </div>

# %%
our_plots.plot_facet_grouped_box(
    df["duration"],
    df["job"],
    df["y"],
    title="Duration vs Subscription Across Job Types",
    x_label="Subscription",
    y_label="Duration",
    facet_label="Job",
    facet_col_wrap=4
)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q28 Is the relationship between balance and success different across marital status?
#   </h3>
# </div>

# %%
our_plots.plot_facet_grouped_box(
    df["balance"],
    df["marital"],
    df["y"],
    title="Balance vs Subscription Across Marital Status",
    x_label="Subscription",
    y_label="Balance",
    facet_label="Marital Status",
    facet_col_wrap=3
)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q29  Is the relationship between age and success different across credit default?
#   </h3>
# </div>

# %%
our_plots.plot_facet_grouped_box(
    df["age"],
    df["default"],
    df["y"],
    title="Age vs Subscription Across Credit Default Status",
    x_label="Subscription",
    y_label="Age",
    facet_label="Credit Default Status",
    facet_col_wrap=3
)

# %% [markdown]
# <div style="
#   width: 97%;
#   margin: 18px 0;
#   padding: 14px 18px;
#   border-radius: 12px;
#   text-align: left;
#   background: rgba(140, 140, 140, 0.10);
#   border: 1px solid rgba(140, 140, 140, 0.18);
#   box-shadow: 0 6px 18px rgba(0,0,0,0.12);
#   backdrop-filter: blur(10px);
#   position: relative;
#   overflow: hidden;
# ">
#   <div style="
#     position: absolute;
#     left: 0;
#     top: 0;
#     bottom: 0;
#     width: 6px;
#     background: linear-gradient(180deg, #5e0ab9 0%, #6a11cb 55%, #3f84fd 100%);
#   "></div>
#   <h3 style="
#     margin: 0;
#     padding-left: 12px;
#     font-family: 'Segoe UI', sans-serif;
#     font-weight: 800;
#     letter-spacing: 1px;
#     font-size: 1.25em;
#     color: inherit;
#   ">
#     3. Q30 	What is the correlation between all numeric features?
#   </h3>
# </div>

# %%
our_plots.plot_correlation_heatmap(df, title="Correlation Heatmap", target_column="y")
